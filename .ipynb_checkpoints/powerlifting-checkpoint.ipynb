# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Introduction:**
#
# Today we will continue exploring the Power lifting data set with some Exploratory Data Analysis. During the exploration we want to get a general idea of what the data is saying and report those insights.
#
# <img src="https://www.openpowerlifting.org/static/images/logo-compressed.e87731f9ce53411287c05e88356bf68e.svg" >

# %%
powerlift = pd.read_csv('powerlift.csv', index_col = 'Unnamed: 0')
powerlift['WILKS Level'] = powerlift['WILKS Level'].replace('Very Hight WILKS', 'Very High WILKS').replace('Hight WILKS', 'High WILKS')
powerlift.head()
# Out:
#    MeetID              Name Sex   Equipment  BodyweightKg WeightClassKg  \
# 0       0  Angie Belk Terry   F       Wraps         59.60            60
# 1       0       Dawn Bogart   F  Single-ply         58.51            60
# 2       0       Dawn Bogart   F         Raw         58.51            60
# 3       0      Destiny Dula   F         Raw         63.68          67.5
# 4       0   Courtney Norris   F       Wraps         62.41          67.5
#
#    BestSquatKg  BestBenchKg  BestDeadliftKg  TotalKg   Wilks Federation  \
# 0        47.63        20.41           70.31   138.35  155.05    Not IPF
# 1       142.88        95.25          163.29   401.42  456.38    Not IPF
# 2         0.00        95.25            0.00    95.25  108.29    Not IPF
# 3         0.00        31.75           90.72   122.47  130.47    Not IPF
# 4       170.10        77.11          145.15   392.36  424.40    Not IPF
#
#        Squat Weight      Bench Weight Deadlift Weight      Total Weight  \
# 0       Light Squat  Very Light Bench   Very Light DL  Very Light Total
# 1    Moderate Squat    Moderate Bench     Moderate DL    Moderate Total
# 2  Very Light Squat    Moderate Bench   Very Light DL  Very Light Total
# 3  Very Light Squat  Very Light Bench   Very Light DL  Very Light Total
# 4    Moderate Squat       Light Bench        Light DL    Moderate Total
#
#        WILKS Level         Cluster Name
# 0   Very Low WILKS       Heavy and Weak
# 1  Very High WILKS  Average and Average
# 2   Very Low WILKS       Heavy and Weak
# 3   Very Low WILKS       Heavy and Weak
# 4  Very High WILKS   Average and Strong

# %% [markdown]
# **Bar Charts:**
# Let's start looking at some data with bar charts! The function below creates a bar chart based on filtering and aggregating our data. We filter the data by defining a column name and choosing a value in that column. We aggregate our data by choosing the column as a group. Here is where the groups that we created are useful. They act as a summary of what the other columns offer in a simple format. This is great for exploring the data at a high level and looking at one categorical variable at a time. Something to keep in mind is that we have to be extra aware of the x values since they are not always listed in an intuitive nor consistent way. For example, the Wilks columns do not go in ascending order (from very low to very high) unless the data follows the same trend.

# %%
def powerlift_barchart(column, value_type, group):
    col_value = powerlift[column] == value_type
    powerlift_value = powerlift[col_value]
    count_group = powerlift_value[group].value_counts()
    ax = sns.barplot(count_group.index, count_group.values)
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 30)
    ax.set(ylabel='Count', xlabel = group)
    ax.set_title(column + "-" + value_type)
    plt.show()

# %% [markdown]
# **Let's explore WILKS scores!** A WILKS score is the most common formula used in strengths sports to determine an athlete's strength relative to their weight. I will look at different columns and values in relation to a WILKS Level.

# %%
powerlift_barchart( 'Equipment', 'Raw', 'WILKS Level')
powerlift_barchart( 'Equipment', 'Wraps', 'WILKS Level')
powerlift_barchart( 'Deadlift Weight', 'Very Heavy DL', 'WILKS Level')
powerlift_barchart( 'Bench Weight', 'Very Heavy Bench', 'WILKS Level')
powerlift_barchart( 'Squat Weight', 'Very Heavy Squat', 'WILKS Level')
powerlift_barchart( 'Sex', 'F', 'WILKS Level')
powerlift_barchart( 'Sex', 'M', 'WILKS Level')

# %% [markdown]
# **Heat Maps:** By pivoting the data and creating a heat map we are able to look at more than one variable at a time. In the function below the last parameter is an arbitrary column. Arbitrary in the sense that it can be any column other than the first two called. If it is not called, then we will have the the same plot given too many times (one for every other column in the dataframe).

# %%
def powerlift_pivot_count(rows, columns, calc_field):
    powerlift_pivot = powerlift.pivot_table(values=calc_field, 
                              index=rows, 
                              columns=columns, 
                              aggfunc=np.size
                             ).dropna(axis=0, how='all')
    sns.heatmap(powerlift_pivot, annot = True, fmt = 'g')
    plt.show()

# %%
powerlift_pivot_count( 'Deadlift Weight', 'Cluster Name', 'Federation')
powerlift_pivot_count( 'Bench Weight', 'Cluster Name', 'Federation')
powerlift_pivot_count( 'Squat Weight', 'Cluster Name', 'Federation')
powerlift_pivot_count( 'Equipment', 'WILKS Level', 'Federation')

# %% [markdown]
# **Pair Plots:** Last we will look at pair plots. These graphs allows us to see whether there is a correlation within the different numeric values. By declaring an optional variable, Hue, we can explore clusters as well. This is useful to see an extra dimension of detail.

# %%
select_columns = ['BodyweightKg', 'BestSquatKg', 'BestBenchKg', 'BestDeadliftKg', 'TotalKg', 'Wilks']
sns.pairplot(powerlift, height = 3, vars = select_columns, hue = 'Cluster Name', plot_kws = { 'alpha': 0.1}).set(xlim = (0), ylim = (0))
plt.show()

# %% [markdown]
# **Insights:**
# * There are more people with Very Low WILKS in the Raw Categories then with with any other WILKS Level.
# * There are more people with Very High WILKS in the Wraps category than with any other WILKS Level.
# * If someone has a very Heavy deadlift there is a good chance they will have a very high WILKS.
# * If someone has a very heavy bench, it is likely they'll have a very high WILKS.
# * If a competitor has a very heavy Squat then it is unlikely that they will have a very low WILKS.
# * More Women have Low WILKS score than any other WILKS category
# * More men have Very High WILKS scores than any other WILKS category. (It is interesting to note that of the top five highest WILKS of the world, none of them are men and of the top ten, three are men.)
# * In terms of weight you are more likely to encounter someone with a very light deadlift that is also heavy, versus a person who is heavy and has  high deadlift.
# * There are more people competing in the raw category than any other category.
# * The squat has the most positive correlation with Total Kg lifted and a high Squat than any other numeric column.

# %% [markdown]
# **Conclusion:**
# We have explored the data above in a general and simple way. The insights are many, and they are great leads to where we can go next.
# The summary statistics are in EDA is not an end but a beginning to understanding the data.
