# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as pl
import seaborn as sns

# %%
powerlift = pd.read_csv('powerlift.csv')
powerlift.head()
# Out:
#    Unnamed: 0  MeetID              Name Sex   Equipment  BodyweightKg  \
# 0           0       0  Angie Belk Terry   F       Wraps         59.60
# 1           1       0       Dawn Bogart   F  Single-ply         58.51
# 2           2       0       Dawn Bogart   F         Raw         58.51
# 3           3       0      Destiny Dula   F         Raw         63.68
# 4           4       0   Courtney Norris   F       Wraps         62.41
#
#   WeightClassKg  BestSquatKg  BestBenchKg  BestDeadliftKg  TotalKg   Wilks  \
# 0            60        47.63        20.41           70.31   138.35  155.05
# 1            60       142.88        95.25          163.29   401.42  456.38
# 2            60         0.00        95.25            0.00    95.25  108.29
# 3          67.5         0.00        31.75           90.72   122.47  130.47
# 4          67.5       170.10        77.11          145.15   392.36  424.40
#
#   Federation      Squat Weight      Bench Weight Deadlift Weight  \
# ...
